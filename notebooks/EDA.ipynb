# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/temperature_observations_colombia.csv")  # default sep=","
df.columns = df.columns.str.strip()

df.head()
# Out:
#    codigoestacion  codigosensor         fechaobservacion  valorobservado  \
# 0        16025501            68  2016-09-20T04:15:00.000        16.10000
# 1        24015503            68  2018-05-05T18:40:00.000        15.43093
# 2        21202220            68  2013-12-14T08:00:00.000        16.70000
# 3        23065503            68  2017-07-04T09:50:00.000        22.60089
# 4        15065040            68  2018-01-26T12:00:00.000        31.40000
#
#       nombreestacion        departamento    municipio  zonahidrografica  \
# 0   CUCUTILLA  - AUT  NORTE DE SANTANDER    CUCUTILLA         CATATUMBO
# 1    CONFINES  - AUT           SANTANDER     CONFINES          SOGAMOSO
# 2    PARAISO - FOPAE         BOGOTA D.C.  BOGOTA, D.C    ALTO MAGDALENA
# 3  EL MIRADOR  - AUT        CUNDINAMARCA      SASAIMA   MEDIO MAGDALENA
# 4   LA PAULINA - AUT          LA GUAJIRA      FONSECA  CARIBE - GUAJIRA
#
#      latitud   longitud descripcionsensor unidadmedida
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   codigoestacion     50000 non-null  int64
#  1   codigosensor       50000 non-null  int64
#  2   fechaobservacion   50000 non-null  object
#  3   valorobservado     50000 non-null  float64
#  4   nombreestacion     50000 non-null  object
#  5   departamento       50000 non-null  object
#  6   municipio          50000 non-null  object
#  7   zonahidrografica   50000 non-null  object
#  8   latitud            50000 non-null  float64
#  9   longitud           50000 non-null  float64
#  10  descripcionsensor  50000 non-null  object
#  11  unidadmedida       50000 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 4.6+ MB

# %%
# Verificacion de nulos
df.isnull().sum()
# Out:
# codigoestacion       0
# codigosensor         0
# fechaobservacion     0
# valorobservado       0
# nombreestacion       0
# departamento         0
# municipio            0
# zonahidrografica     0
# latitud              0
# longitud             0
# descripcionsensor    0
# unidadmedida         0
# dtype: int64

# %%
# Revision de duplicados
grain = ["codigoestacion", "codigosensor", "fechaobservacion"]

df.duplicated(subset=grain).sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated(subset=grain, keep=False)]
# Out:
# Empty DataFrame
# Columns: [codigoestacion, codigosensor, fechaobservacion, valorobservado, nombreestacion, departamento, municipio, zonahidrografica, latitud, longitud, descripcionsensor, unidadmedida]
# Index: []

# %%
# validacion de tipos
df.dtypes
# Out:
# codigoestacion         int64
# codigosensor           int64
# fechaobservacion      object
# valorobservado       float64
# nombreestacion        object
# departamento          object
# municipio             object
# zonahidrografica      object
# latitud              float64
# longitud             float64
# descripcionsensor     object
# unidadmedida          object
# dtype: object

# %%
df["valorobservado"].describe()
# Out:
# count    50000.000000
# mean        18.660062
# std          6.388992
# min          0.000000
# 25%         15.100000
# 50%         18.500000
# 75%         22.828557
# max         50.000000
# Name: valorobservado, dtype: float64

# %%
# Revision de formatos inconsistentes
df["unidadmedida"].unique()
# Out:
# array(['°C'], dtype=object)

# %%
df["departamento"].unique()[:10]
# Out:
# array(['NORTE DE SANTANDER', 'SANTANDER', 'BOGOTA D.C.', 'CUNDINAMARCA',
#        'LA GUAJIRA', 'ANTIOQUIA', 'CALDAS', 'HUILA', 'CORDOBA', 'CAUCA'],
#       dtype=object)

# %%
df["municipio"].unique()[:10]
# Out:
# array(['CUCUTILLA', 'CONFINES', 'BOGOTA, D.C', 'SASAIMA', 'FONSECA',
#        'SANTA BÁRBARA', 'SUPIA', 'TELLO', 'MONTERÍA', 'LA SIERRA'],
#       dtype=object)

# %%
# Verificacion de fechas 
df["fechaobservacion"] = pd.to_datetime(df["fechaobservacion"], errors="coerce")
df["fechaobservacion"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Verificacion de rango geografico
df["latitud"].describe()
# Out:
# count    50000.000000
# mean         5.004974
# std          2.052197
# min         -4.194000
# 25%          4.343000
# 50%          4.718611
# 75%          5.625831
# max         15.797000
# Name: latitud, dtype: float64

# %%
df["longitud"].describe()
# Out:
# count    50000.000000
# mean       -74.880448
# std          1.871863
# min        -81.731000
# 25%        -75.793333
# 50%        -75.003136
# 75%        -74.072000
# max          0.000000
# Name: longitud, dtype: float64

# %%
df[df["longitud"] == 0]
# Out:
#        codigoestacion  codigosensor    fechaobservacion  valorobservado  \
# 1074         24037620            68 2013-11-26 05:00:00            12.8
# 3394         24037620            68 2014-08-02 02:00:00             6.4
# 3760         24037620            68 2014-07-12 18:00:00            11.0
# 4573         24037620            68 2014-03-05 08:00:00             9.1
# 7490         24037620            68 2014-05-17 07:00:00             6.1
# 8312         88112901            68 2018-02-02 07:20:00            21.1
# 11245        88112901            68 2017-04-18 01:36:00            22.6
# 14288        88112901            68 2017-03-27 12:20:00            19.1
# 15786        24037620            68 2014-06-22 03:00:00             7.4
# 17900        88112901            68 2018-02-11 10:35:00            23.5
# 21139        24037620            68 2014-05-07 22:00:00            13.9
# 22184        24037620            68 2014-04-07 01:00:00             8.1
# ...

# %%
(df == "<nil>").sum()
# Out:
# codigoestacion        0
# codigosensor          0
# fechaobservacion      0
# valorobservado        0
# nombreestacion        0
# departamento         15
# municipio            15
# zonahidrografica     89
# latitud               0
# longitud              0
# descripcionsensor     0
# unidadmedida          0
# dtype: int64
